# %%
a=10
for i in range(a):
    print(i,"Kunal")
print("Thanks")
# Out:
# 0 Kunal
# 1 Kunal
# 2 Kunal
# 3 Kunal
# 4 Kunal
# 5 Kunal
# 6 Kunal
# 7 Kunal
# 8 Kunal
# 9 Kunal
# Thanks

# %%
# Out:
# 10 hello world
# 9 hello world
# 8 hello world
# 7 hello world
# 6 hello world
# 5 hello world
# 4 hello world
# 3 hello world
# 2 hello world
# 1 hello world
# 0 hello world
# -1 hello world
# -2 hello world
# -3 hello world
# -4 hello world
# -5 hello world
# -6 hello world
# -7 hello world
# -8 hello world
# -9 hello world
# -10 hello world
# -11 hello world
# -12 hello world
# -13 hello world
# -14 hello world
# -15 hello world
# -16 hello world
# -17 hello world
# -18 hello world
# -19 hello world
# -20 hello world
# -21 hello world
# -22 hello world
# -23 hello world
# -24 hello world
# -25 hello world
# -26 hello world
# -27 hello world
# -28 hello world
# -29 hello world
# -30 hello world
# -31 hello world
# -32 hello world
# -33 hello world
# -34 hello world
# -35 hello world
# -36 hello world
# -37 hello world
# -38 hello world
# -39 hello world
# -40 hello world
# -41 hello world
# -42 hello world
# -43 hello world
# -44 hello world
# -45 hello world
# -46 hello world
# ...

# %%
print("Welcome\n")

print("Kunal Singh Teotia")
print("contact number:8430817591")
print("hometown:BSR")
while True:
    p=1234
    pa_ss=int(input("Enter pass:"))
    if p==pa_ss:
        print("acc:DBS bank")
        print("acc. num:8430817591")


        while True:
            ab=9876
            pa=int(input("Enter id pass:"))
            if ab==pa:
                print("bal:500000000")
                print("atm pin:8430")
                break
            
            else:
                print("wrong personal pass")
            choice=input("Do you want to try again:y/n\n")
            if choice=="n":
                break
            elif choice!="y":
                print("wrong choice\nTry again")
        break
    else:
        print("Wrong Password")    
    choice=input("Do you want to try again:y/n\n")
    if choice=="n":
        break  
    elif choice!="y":
        print("wrong choice loop ended")
        break
print("\nThanks")

# %%
a=550
c=67
a=a-c
a
# Out:
# 483

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f091b0e4988e> in <module>
#       1 A=250
#       2 for i in range(A):
# ----> 3     print(ord(i))
#
# TypeError: ord() expected string of length 1, but int found

# %%
r=5
for i in range(r,0,-1):
    print("1"*i)
# Out:
# 11111
# 1111
# 111
# 11
# 1

# %%
num=int(input("Enter Number"))
k=num-1
for i in range(num,0,-1):
    a=(i*2)-1
    for j in range(k, 0,-1):
        print(end=" ")
        k = k +1
        for j in range(0,a,1) :
            print(end="")
            if j %2==0:
                print(1,end=" ")
            else:
                print(0,end=" ")
        print()
# Out:
# Enter Number2
#  1 0 1
#  1
#  1

# %%
i=1
n=int(input("Entr a number :"))
while i<=n:
    print(i,'pushpendra sharma')
    m=int(input("Enter m :"))
    y=9/m
    i+=1
else:
    print("my while finished")
# Out:
# Entr a number :5
# 1 pushpendra sharma
# Enter m :10
# 2 pushpendra sharma
# Enter m :2
# 3 pushpendra sharma
# Enter m :3
# 4 pushpendra sharma
# Enter m :1
# 5 pushpendra sharma
# Enter m :23
# my while finished

# %%
n=5
for i in range(1):
    for j in range(n):
        print(j*"*")
    for k in range(n+1,0,-1):
        print((k-1)*"*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
n=5 
for i in range(1):
    for j in range(n):
        print(" "*(n-i),j*"*")
    for k in range(n+1,0,-1):
        print((k-1)*"*")
# Out:
#
#       *
#       **
#       ***
#       ****
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(1):
    for j in range(n):
        print(j*"*")
# Out:
# *
# **
# ***
# ****

# %%
n=5
for i in range(n+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n+1):
    print(" "*(n-i),i*"*")
# Out:
#
#      *
#     **
#    ***
#   ****
#  *****

# %%
n=5
for i in range(n,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(n,0,-1):
    print(" "*(n-i),i*"*")
# Out:
#  *****
#   ****
#    ***
#     **
#      *

# %%
n=5
for i in range(1):
    for j in range(n):
        print(" "*(n-j),"*"*j)
    for k in range(n,0,-1):
        print(" "*(n-k),k*"*")
# Out:
#
#      *
#     **
#    ***
#   ****
#  *****
#   ****
#    ***
#     **
#      *

# %%
for i in range(1):
    for j in range(n):
        print("*"*j)
    for k in range(n,0,-1):
        print("*"*k)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1):
    for j in range(n):
        print("*"*j)
for k in range(n,0,-1):
        print("*"*k)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1):
    for j in range(n):
        print(("*"*j)," "*(n-j),j*"*")
# Out:
#
# *      *
# **     **
# ***    ***
# ****   ****

# %%
n=15
for i in range(n+1):
    print(" "*(n-(2*i)) ,i*"*")
for i in range(n,0,-1):
    print(" "*(n-(2*i)) ,i*"*")
# Out:
#
#               *
#             **
#           ***
#         ****
#       *****
#     ******
#   *******
#  ********
#  *********
#  **********
#  ***********
#  ************
#  *************
#  **************
#  ***************
#  ***************
#  **************
#  *************
#  ************
#  ***********
#  **********
#  *********
#  ********
#   *******
#     ******
#       *****
#         ****
#           ***
#             **
#               *

# %%
k=2*n-2
for i in range(n):
    for j in range(0,k):
        print(end=" ")
    k=k-1
    for j in range(i+1):
        print("*",end=" ")
    print("\r")
# Out:
#                             *
#                            * *
#                           * * *
#                          * * * *
#                         * * * * *
#                        * * * * * *
#                       * * * * * * *
#                      * * * * * * * *
#                     * * * * * * * * *
#                    * * * * * * * * * *
#                   * * * * * * * * * * *
#                  * * * * * * * * * * * *
#                 * * * * * * * * * * * * *
#                * * * * * * * * * * * * * *
#               * * * * * * * * * * * * * * *

# %%
k = 2 * n - 2
for i in range(0,n):
    for j in range(0,k):
        print(end=" ")
    k = k - 1
    for j in range(0, i+1):
        print("*", end=" ")
    print("\r")
# Out:
#         *
#        * *
#       * * *
#      * * * *
#     * * * * *

# %%
# Out:
#   File "<ipython-input-2-151b4741c3d5>", line 4
#     for j in range()
#                     ^
# SyntaxError: invalid syntax
